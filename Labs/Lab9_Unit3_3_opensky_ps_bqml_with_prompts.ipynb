# %% [markdown]
# ## This notebook implements a streaming architecture:
#
# Producer: Fetches live data from OpenSky and publishes it to a Google Cloud Pub/Sub Topic.
#
# Consumer: Pulls messages from the Pub/Sub Subscription, streams them into a new BigQuery table (realtime_flight_data), and immediately runs predictions using your existing BQML models.

# %% [markdown]
# ## 1. Setup and Authentication

# %% [markdown]
# Context: Installs necessary Google Cloud libraries and handles Colab authentication.
#
# Prompt: "Write a Python code block for Google Colab that performs the following:
#
# Installs the google-cloud-pubsub, google-cloud-bigquery, google-cloud-storage, and requests libraries via pip.
#
# Imports auth from google.colab and authenticates the user to the Google Cloud environment."

# %%
# Install required packages
# !pip install google-cloud-pubsub google-cloud-bigquery google-cloud-storage requests

from google.colab import auth
print("Authenticating to Google Cloud...")
auth.authenticate_user()
print("Authentication successful.")
# Out:
# Collecting google-cloud-pubsub
#   Downloading google_cloud_pubsub-2.33.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: google-cloud-bigquery in /usr/local/lib/python3.12/dist-packages (3.38.0)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: grpcio<2.0.0,>=1.51.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub) (1.76.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub) (2.38.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (2.28.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub) (5.29.5)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub) (0.14.3)
# Requirement already satisfied: grpcio-status>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub) (1.71.2)
# Requirement already satisfied: opentelemetry-api>=1.27.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk>=1.27.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub) (1.37.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery) (2.7.2)
# Requirement already satisfied: packaging>=24.2.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery) (25.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery) (2.9.0.post0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (1.7.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.10.5)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (1.72.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-pubsub) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-pubsub) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-pubsub) (4.9.1)
# Requirement already satisfied: typing-extensions~=4.12 in /usr/local/lib/python3.12/dist-packages (from grpcio<2.0.0,>=1.51.3->google-cloud-pubsub) (4.15.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api>=1.27.0->google-cloud-pubsub) (8.7.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk>=1.27.0->google-cloud-pubsub) (0.58b0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery) (1.17.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.27.0->google-cloud-pubsub) (3.23.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-cloud-pubsub) (0.6.1)
# Downloading google_cloud_pubsub-2.33.0-py3-none-any.whl (321 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.3/321.3 kB 6.0 MB/s eta 0:00:00
# Installing collected packages: google-cloud-pubsub
# Successfully installed google-cloud-pubsub-2.33.0
# Authenticating to Google Cloud...
# Authentication successful.

# %% [markdown]
# ## Cell 2: Configuration Variables

# %% [markdown]
# Context: Defines global variables for Project ID, Pub/Sub resources, and BigQuery resources.
#
# Prompt: "Create a configuration cell that defines Python variables for a Google Cloud project. Specifically, define:
#
# PROJECT_ID (e.g., 'mgmt-467-47888')
#
# REGION (e.g., 'us-central1')
#
# TOPIC_NAME (e.g., 'opensky-realtime-topic')
#
# SUBSCRIPTION_NAME (e.g., 'opensky-realtime-sub')
#
# BQ_DATASET (e.g., 'training_dataset')
#
# BQ_TABLE_REALTIME (e.g., 'realtime_flight_data')
#
# MODEL_NAME (e.g., 'flight_velocity_predictor')
#
# Finally, execute a shell command to set the gcloud config project to the defined PROJECT_ID."

# %%
# --- Configuration ---
PROJECT_ID = "heroic-trilogy-471119-k8"
REGION = "us-central1"

# Pub/Sub Configuration
TOPIC_NAME = "opensky-realtime-topic"
SUBSCRIPTION_NAME = "opensky-realtime-sub"

# BigQuery Configuration
BQ_DATASET = "training_dataset"
BQ_TABLE_REALTIME = "realtime_flight_data" # New table for streaming data
MODEL_NAME = "flight_velocity_predictor"   # The model we made in Unit 3.2

# Set the project for gcloud commands
# !gcloud config set project $PROJECT_ID
# Out:
# INFORMATION: Project 'heroic-trilogy-471119-k8' has no 'environment' tag set. Use either 'Production', 'Development', 'Test', or 'Staging'. Add an 'environment' tag using `gcloud resource-manager tags bindings create`.
# Updated property [core/project].

# %% [markdown]
# ## Cell 3: Infrastructure Setup (Idempotent)

# %% [markdown]
# Context: Uses Python clients to create the Topic, Subscription, Dataset, and Table if they don't already exist.
#
# Prompt: "Write a Python script using the Google Cloud SDK (google.cloud) to set up infrastructure idempotently. The script should:
#
# Initialize Pub/Sub and BigQuery clients.
#
# Create a Pub/Sub Topic if it doesn't exist.
#
# Create a Pub/Sub Subscription to that topic if it doesn't exist.
#
# Create a BigQuery Dataset if it doesn't exist.
#
# Create a BigQuery Table named realtime_flight_data if it doesn't exist.
#
# Use a schema for the table that includes fields for OpenSky data: icao24 (STRING), callsign (STRING), origin_country (STRING), time_position (INTEGER), longitude (FLOAT), latitude (FLOAT), geo_altitude (FLOAT), on_ground (BOOLEAN), velocity (FLOAT), heading (FLOAT), vertical_rate (FLOAT), and sensor_timestamp (TIMESTAMP). Handle AlreadyExists exceptions gracefully."

# %%
from google.cloud import pubsub_v1, bigquery
from google.api_core.exceptions import NotFound, AlreadyExists

# Initialize clients
publisher_client = pubsub_v1.PublisherClient()
subscriber_client = pubsub_v1.SubscriberClient()
bq_client = bigquery.Client()

# Construct full resource paths
topic_path = publisher_client.topic_path(PROJECT_ID, TOPIC_NAME)
subscription_path = subscriber_client.subscription_path(PROJECT_ID, SUBSCRIPTION_NAME)

# 1. Create Pub/Sub Topic if it doesn't exist
print(f"Checking Pub/Sub Topic: {TOPIC_NAME}...")
try:
    publisher_client.get_topic(request={"topic": topic_path})
    print(f"Topic {TOPIC_NAME} already exists.")
except NotFound:
    try:
        publisher_client.create_topic(request={"name": topic_path})
        print(f"Topic {TOPIC_NAME} created.")
    except AlreadyExists:
        print(f"Topic {TOPIC_NAME} already exists (concurrent creation).")

# 2. Create Pub/Sub Subscription if it doesn't exist
print(f"Checking Pub/Sub Subscription: {SUBSCRIPTION_NAME}...")
try:
    subscriber_client.get_subscription(request={"subscription": subscription_path})
    print(f"Subscription {SUBSCRIPTION_NAME} already exists.")
except NotFound:
    try:
        # The topic must exist before creating a subscription to it
        subscriber_client.create_subscription(
            request={"name": subscription_path, "topic": topic_path}
        )
        print(f"Subscription {SUBSCRIPTION_NAME} created.")
    except AlreadyExists:
        print(f"Subscription {SUBSCRIPTION_NAME} already exists (concurrent creation).")

# 3. Create BigQuery Dataset if it doesn't exist
dataset_id = f"{PROJECT_ID}.{BQ_DATASET}"
dataset = bigquery.Dataset(dataset_id)

print(f"Checking BigQuery Dataset: {BQ_DATASET}...")
try:
    bq_client.get_dataset(dataset_id)
    print(f"Dataset {BQ_DATASET} already exists.")
except NotFound:
    try:
        dataset = bq_client.create_dataset(dataset)
        print(f"Dataset {BQ_DATASET} created.")
    except AlreadyExists:
        print(f"Dataset {BQ_DATASET} already exists (concurrent creation).")

# 4. Create BigQuery Table if it doesn't exist
table_id = f"{PROJECT_ID}.{BQ_DATASET}.{BQ_TABLE_REALTIME}"

# Define the schema for the realtime_flight_data table
schema = [
    bigquery.SchemaField("icao24", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("callsign", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("origin_country", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("time_position", "INTEGER", mode="NULLABLE"),
    bigquery.SchemaField("last_contact", "INTEGER", mode="NULLABLE"),
    bigquery.SchemaField("longitude", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("latitude", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("baro_altitude", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("geo_altitude", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("on_ground", "BOOLEAN", mode="NULLABLE"),
    bigquery.SchemaField("velocity", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("heading", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("vertical_rate", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("squawk", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("spi", "BOOLEAN", mode="NULLABLE"),
    bigquery.SchemaField("position_source", "INTEGER", mode="NULLABLE"),
    bigquery.SchemaField("sensor_timestamp", "TIMESTAMP", mode="NULLABLE"), # Timestamp for when the data was processed
]

table = bigquery.Table(table_id, schema=schema)

print(f"Checking BigQuery Table: {BQ_TABLE_REALTIME}...")
try:
    bq_client.get_table(table_id)
    print(f"Table {BQ_TABLE_REALTIME} already exists.")
except NotFound:
    try:
        table = bq_client.create_table(table)
        print(f"Table {BQ_TABLE_REALTIME} created.")
    except AlreadyExists:
        print(f"Table {BQ_TABLE_REALTIME} already exists (concurrent creation).")

print("All required Google Cloud resources are ready.")
# Out:
# Checking Pub/Sub Topic: opensky-realtime-topic...
# Topic opensky-realtime-topic created.
# Checking Pub/Sub Subscription: opensky-realtime-sub...
# Subscription opensky-realtime-sub created.
# Checking BigQuery Dataset: training_dataset...
# Dataset training_dataset already exists.
# Checking BigQuery Table: realtime_flight_data...
# Table realtime_flight_data created.
# All required Google Cloud resources are ready.

# %% [markdown]
# ## Cell 4: OpenSky API Class Helper

# %% [markdown]
# Context: A helper class to interact with the REST API.
#
# Prompt: "Write a Python class named OpenSkyApi. The constructor should accept a username and password. Include a method named get_states that accepts bounding box coordinates (lmin, lmax, hmin, hmax) or an icao24 code. The method should make a GET request to https://opensky-network.org/api/states/all and return the list of flight states from the JSON response."

# %%
import requests
from collections import defaultdict

OPEN_SKY_USERNAME = "none"
OPEN_SKY_PASSWORD = "none"

class OpenSkyApi(object):
    def __init__(self, username, password):
        self._auth = (username, password)
        self._api_url = "https://opensky-network.org/api"
        self._last_requests = defaultdict(lambda: 0)

    def get_states(self, icao24=None, time_sec=None, lmin=None, lmax=None, hmin=None, hmax=None):
        params = {}
        if icao24:
            params['icao24'] = icao24
        if time_sec:
            params['time'] = time_sec
        if lmin is not None:
            params['lamin'] = lmin
        if lmax is not None:
            params['lamax'] = lmax
        if hmin is not None:
            params['lomin'] = hmin
        if hmax is not None:
            params['lomax'] = hmax

        try:
            response = requests.get(f"{self._api_url}/states/all",
                                    params=params,
                                    auth=self._auth)
            response.raise_for_status()
            data = response.json()
            return data.get('states', [])
        except requests.exceptions.RequestException as e:
            print(f"Error fetching OpenSky data: {e}")
            return []

# %% [markdown]
# ## 5. Data Processing and Publishing Function
#
# Context: Parses API data, cleans it, and pushes JSON messages to Pub/Sub.
#
# Prompt: "Create a function named process_and_publish that takes an OpenSky API response, a Pub/Sub publisher client, and a topic path.
#
# The function should:
#
# Iterate through the flight states.
#
# Map the raw list data to a dictionary with keys matching a BigQuery schema (icao24, callsign, longitude, latitude, velocity, geo_altitude, etc.).
#
# Add a current UTC timestamp field named sensor_timestamp.
#
# Filter out any records where velocity or geo_altitude are None.
#
# Publish the valid records as JSON strings to the Pub/Sub topic.
#
# Return the count of published messages."

# %%
import json
import datetime
from google.cloud import pubsub_v1

publisher_client = pubsub_v1.PublisherClient() # Re-initialize client if not globally available after split

def process_and_publish(api_response, publisher_client, topic_path):
    """Parses API response and publishes each flight as a Pub/Sub message, then cleans and filters."""
    if not api_response or 'states' not in api_response or api_response['states'] is None:
        print("No flight data received from OpenSky API.")
        return 0

    published_count = 0
    current_utc_timestamp = datetime.datetime.utcnow().isoformat() + "Z"

    for state_vector in api_response['states']:
        data = {
            "icao24": state_vector[0],
            "callsign": state_vector[1].strip() if state_vector[1] else None,
            "origin_country": state_vector[2].strip() if state_vector[2] else None,
            "time_position": state_vector[3],
            "last_contact": state_vector[4],
            "longitude": state_vector[5],
            "latitude": state_vector[6],
            "baro_altitude": state_vector[7],
            "geo_altitude": state_vector[13],
            "on_ground": state_vector[8],
            "velocity": state_vector[9],
            "heading": state_vector[10],
            "vertical_rate": state_vector[11],
            "squawk": state_vector[14] if len(state_vector) > 14 else None,
            "spi": state_vector[15] if len(state_vector) > 15 else None,
            "position_source": state_vector[16] if len(state_vector) > 16 else None,
            "sensor_timestamp": current_utc_timestamp,
        }

        if data['velocity'] is not None and data['geo_altitude'] is not None:
            message_json_string = json.dumps(data)
            message_bytes = message_json_string.encode("utf-8")
            future = publisher_client.publish(topic_path, message_bytes)
            published_count += 1
        else:
            print(f"Skipping record due to missing velocity or geo_altitude for icao24: {state_vector[0]}")
    return published_count

# %% [markdown]
# ## 6. Subscriber and Prediction Function
# Context: Pulls messages, inserts to BQ, and runs an ML.PREDICT query immediately.
#
# Prompt: "Write a function named pull_and_insert_and_predict that runs for a specified timeout period.
#
# Inside the function:
#
# Subscribe to the Pub/Sub subscription.
#
# When a message is received, parse the JSON data.
#
# Insert the row immediately into the BigQuery table realtime_flight_data.
#
# Upon successful insertion, run a BigQuery SQL query using ML.PREDICT with the model flight_velocity_predictor. The query should predict the velocity for the specific flight (identified by icao24 and sensor_timestamp) that was just inserted.
#
# Print the prediction results and acknowledge the Pub/Sub message."

# %%
import google.cloud.pubsub_v1 as pubsub_v1_module
import google.cloud.bigquery as bigquery_module
from concurrent.futures import TimeoutError
import pandas as pd # Import pandas for DataFrame conversion

subscriber_client = pubsub_v1_module.SubscriberClient() # Re-initialize client if not globally available after split
bq_client = bigquery_module.Client(project=PROJECT_ID) # Explicitly pass PROJECT_ID here

# Define resource paths/IDs within this cell for reliability
subscription_path = subscriber_client.subscription_path(PROJECT_ID, SUBSCRIPTION_NAME)
table_id = f"{PROJECT_ID}.{BQ_DATASET}.{BQ_TABLE_REALTIME}"

def pull_and_insert_and_predict(timeout=60):
    """Pulls messages from Pub/Sub, inserts into BigQuery, and runs BQML prediction.
    Returns a list of prediction results.
    """
    all_predictions = [] # List to store all prediction results

    def callback(message):
        print(f"Received message: {message.data.decode('utf-8')}")
        try:
            data_json = json.loads(message.data.decode('utf-8'))

            rows_to_insert = [data_json]
            errors = bq_client.insert_rows_json(table_id, rows_to_insert)

            if errors:
                print(f"Errors occurred during BigQuery insert: {errors}")
            else:
                print(f"Successfully inserted row for icao24={data_json.get('icao24')} into {table_id}")

                predict_query = f"""
                SELECT
                    *
                FROM
                    ML.PREDICT(MODEL `{PROJECT_ID}.{BQ_DATASET}.{MODEL_NAME}`,
                        (SELECT
                            geo_altitude AS altitude, # Alias geo_altitude to altitude
                            vertical_rate,
                            heading
                         FROM
                            `{PROJECT_ID}.{BQ_DATASET}.{BQ_TABLE_REALTIME}`
                         WHERE
                            icao24 = '{data_json['icao24']}'
                            AND sensor_timestamp = TIMESTAMP('{data_json['sensor_timestamp']}')
                         LIMIT 1))
                """
                predict_job = bq_client.query(predict_query)
                prediction_results = predict_job.result()

                for row in prediction_results:
                    prediction_dict = dict(row.items()) # Convert Row object to dictionary
                    all_predictions.append(prediction_dict) # Store the prediction result
                    print(f"BQML Prediction for icao24 {data_json['icao24']}: {prediction_dict}")
        except Exception as e:
            print(f"Error processing message or during BQML prediction: {e}")
        finally:
            message.ack()

    streaming_pull_future = subscriber_client.subscribe(subscription_path, callback=callback)
    print(f"Listening for messages on {subscription_path}... (Timeout: {timeout} seconds)\n")

    try:
        streaming_pull_future.result(timeout=timeout)
    except TimeoutError:
        streaming_pull_future.cancel()
        streaming_pull_future.result()
        print("Listening timed out. No messages received within the specified duration.")
    except Exception as e:
        print(f"An error occurred during streaming pull: {e}")
        streaming_pull_future.cancel()
        streaming_pull_future.result()

    return all_predictions

# %% [markdown]
# ## 7. Main Execution (Publisher Loop)
#
# Context: Fetches live data and calls the publish function.
#
# Prompt: "Write a script to execute the pipeline.
#
# Initialize the OpenSkyApi client (using placeholder credentials if necessary).
#
# Call the API to get flight states for a bounding box around Los Angeles (approx lat 34.0 to 34.5, lon -118.5 to -118.0).
#
# Initialize the Pub/Sub publisher client.
#
# Call the process_and_publish function to send the data to Pub/Sub.
#
# Print the number of messages successfully published."

# %%
print("Fetching flight data from OpenSky and publishing to Pub/Sub...")

# Ensure configuration variables are accessible
# TOPIC_ID, PROJECT_ID, OPEN_SKY_USERNAME, OPEN_SKY_PASSWORD are expected to be defined globally
#TOPIC_NAME = TOPIC_ID # Aligning with how other functions expect TOPIC_NAME

# Initialize OpenSky API client
opensky_api = OpenSkyApi(OPEN_SKY_USERNAME, OPEN_SKY_PASSWORD)

# Fetch states for a specific region (e.g., around a major airport)
# Adjust these coordinates as needed for your desired coverage area
lmin = 34.0
lmax = 34.5
hmin = -118.5
hmax = -118.0

states = opensky_api.get_states(lmin=lmin, lmax=lmax, hmin=hmin, hmax=hmax)

if states:
    # Initialize publisher client (if not already done globally)
    publisher_client = pubsub_v1.PublisherClient()

    # Topic path is already defined from configuration cell
    topic_path = publisher_client.topic_path(PROJECT_ID, TOPIC_NAME) # Using the now-defined TOPIC_NAME

    published_count = process_and_publish({'states': states}, publisher_client, topic_path)
    print(f"Successfully published {published_count} messages to Pub/Sub topic {TOPIC_NAME}.")
else:
    print("No states received from OpenSky API or an error occurred. No messages published.")
# Out:
# Fetching flight data from OpenSky and publishing to Pub/Sub...
# Skipping record due to missing velocity or geo_altitude for icao24: a3d0e6
# Skipping record due to missing velocity or geo_altitude for icao24: a75abe
# Skipping record due to missing velocity or geo_altitude for icao24: a37d66
# Skipping record due to missing velocity or geo_altitude for icao24: a7e58a
# Skipping record due to missing velocity or geo_altitude for icao24: a4835c
# Successfully published 16 messages to Pub/Sub topic opensky-realtime-topic.
# /tmp/ipython-input-230726547.py:14: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   current_utc_timestamp = datetime.datetime.utcnow().isoformat() + "Z"

# %% [markdown]
# ## 8. Main Execution (Subscriber/Predictor)
#
# Context: Runs the subscriber to process the data sent in the previous step.
#
# Prompt: "Write a code block to run the pull_and_insert_and_predict function with a timeout of 60 seconds. Capture the returned predictions into a Pandas DataFrame. If predictions exist, display the head of the DataFrame; otherwise, print that no messages were received."

# %%
print("Starting to pull messages and generate predictions...")
# Run the pull_and_insert_and_predict function and get the results
predictions_list = pull_and_insert_and_predict(timeout=60) # You can adjust the timeout as needed

if predictions_list:
    predictions_df = pd.DataFrame(predictions_list)
    print("\nBQML Prediction Results (DataFrame Head):")
    display(predictions_df.head())
else:
    print("No predictions were generated or received within the timeout period.")
# Out:
# Starting to pull messages and generate predictions...
# Listening for messages on projects/heroic-trilogy-471119-k8/subscriptions/opensky-realtime-sub... (Timeout: 60 seconds)
#
# Received message: {"icao24": "a9a120", "callsign": "N7199S", "origin_country": "United States", "time_position": 1763671924, "last_contact": 1763671924, "longitude": -118.2294, "latitude": 34.0224, "baro_altitude": 396.24, "geo_altitude": 381, "on_ground": false, "velocity": 71.74, "heading": 259.25, "vertical_rate": -0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:52:14.633274Z"}
# Received message: {"icao24": "aade5d", "callsign": "N8NF", "origin_country": "United States", "time_position": 1763671818, "last_contact": 1763671826, "longitude": -118.1747, "latitude": 34.196, "baro_altitude": 579.12, "geo_altitude": 548.64, "on_ground": false, "velocity": 40.75, "heading": 204.62, "vertical_rate": -5.2, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:52:14.633274Z"}
# Received message: {"icao24": "a5e790", "callsign": "N48PL", "origin_country": "United States", "time_position": 1763671924, "last_contact": 1763671924, "longitude": -118.443, "latitude": 34.2054, "baro_altitude": 1958.34, "geo_altitude": 1943.1, "on_ground": false, "velocity": 119.25, "heading": 351.07, "vertical_rate": 15.28, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:52:14.633274Z"}
# Received message: {"icao24": "a5e739", "callsign": "N48KZ", "origin_country": "United States", "time_position": 1763671922, "last_contact": 1763671923, "longitude": -118.4903, "latitude": 34.2084, "baro_altitude": 228.6, "geo_altitude": 205.74, "on_ground": false, "velocity": 50.58, "heading": 175.33, "vertical_rate": -0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:52:14.633274Z"}
# Received message: {"icao24": "aadf08", "callsign": "N8VB", "origin_country": "United States", "time_position": 1763671916, "last_contact": 1763671924, "longitude": -118.4928, "latitude": 34.2076, "baro_altitude": 213.36, "geo_altitude": 320.04, "on_ground": false, "velocity": 0, "heading": 0, "vertical_rate": -0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:52:14.633274Z"}
# Received message: {"icao24": "a299f9", "callsign": "N267LA", "origin_country": "United States", "time_position": 1763671924, "last_contact": 1763671924, "longitude": -118.2685, "latitude": 34.0806, "baro_altitude": 312.42, "geo_altitude": 304.8, "on_ground": false, "velocity": 33.99, "heading": 320.53, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:52:14.633274Z"}
# Received message: {"icao24": "ab351f", "callsign": "N821FR", "origin_country": "United States", "time_position": 1763671924, "last_contact": 1763671924, "longitude": -118.4442, "latitude": 34.0219, "baro_altitude": 99.06, "geo_altitude": 68.58, "on_ground": false, "velocity": 27.28, "heading": 225.76, "vertical_rate": -2.93, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:52:14.633274Z"}
# Received message: {"icao24": "acf1ac", "callsign": "JSX181", "origin_country": "United States", "time_position": 1763671924, "last_contact": 1763671924, "longitude": -118.4949, "latitude": 34.1998, "baro_altitude": 899.16, "geo_altitude": 876.3, "on_ground": false, "velocity": 69.46, "heading": 90.85, "vertical_rate": 0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:52:14.633274Z"}
# Received message: {"icao24": "a5c983", "callsign": "N472LA", "origin_country": "United States", "time_position": 1763671923, "last_contact": 1763671924, "longitude": -118.2428, "latitude": 34.1146, "baro_altitude": 327.66, "geo_altitude": 312.42, "on_ground": false, "velocity": 34.68, "heading": 147.72, "vertical_rate": 0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:52:14.633274Z"}
# Received message: {"icao24": "a0c1d7", "callsign": "EJA148", "origin_country": "United States", "time_position": 1763671924, "last_contact": 1763671924, "longitude": -118.3016, "latitude": 34.2763, "baro_altitude": 2110.74, "geo_altitude": 2095.5, "on_ground": false, "velocity": 134.64, "heading": 328.44, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:52:14.633274Z"}
# Successfully inserted row for icao24=a9a120 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=a5e739 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=aade5d into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=a5e790 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=a5c983 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=a299f9 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=ab351f into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=a0c1d7 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=acf1ac into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=aadf08 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# BQML Prediction for icao24 acf1ac: {'predicted_velocity': 89.94515792558508, 'altitude': 876.3, 'vertical_rate': 0.33, 'heading': 90.85}
# Received message: {"icao24": "a384f8", "callsign": "DAL483", "origin_country": "United States", "time_position": 1763671923, "last_contact": 1763671923, "longitude": -118.4491, "latitude": 34.2946, "baro_altitude": 2407.92, "geo_altitude": 2385.06, "on_ground": false, "velocity": 149.96, "heading": 3.34, "vertical_rate": 12.35, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:52:14.633274Z"}
# BQML Prediction for icao24 a5e790: {'predicted_velocity': 84.41613433747922, 'altitude': 1943.1, 'vertical_rate': 15.28, 'heading': 351.07}
# Received message: {"icao24": "aaf0c3", "callsign": "ASA505", "origin_country": "United States", "time_position": 1763671924, "last_contact": 1763671924, "longitude": -118.4684, "latitude": 34.0115, "baro_altitude": 2232.66, "geo_altitude": 2225.04, "on_ground": false, "velocity": 139.24, "heading": 94.03, "vertical_rate": -3.9, "squawk": "1660", "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:52:14.633274Z"}
# BQML Prediction for icao24 aade5d: {'predicted_velocity': 76.9487176503731, 'altitude': 548.64, 'vertical_rate': -5.2, 'heading': 204.62}
# Received message: {"icao24": "aa7833", "callsign": "DAL1715", "origin_country": "United States", "time_position": 1763671924, "last_contact": 1763671924, "longitude": -118.1568, "latitude": 34.0179, "baro_altitude": 838.2, "geo_altitude": 830.58, "on_ground": false, "velocity": 91.64, "heading": 173.55, "vertical_rate": -3.25, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:52:14.633274Z"}
# BQML Prediction for icao24 a5e739: {'predicted_velocity': 73.9206531720971, 'altitude': 205.74, 'vertical_rate': -0.33, 'heading': 175.33}
# Received message: {"icao24": "ae277c", "callsign": "GH08", "origin_country": "United States", "time_position": 1763671923, "last_contact": 1763671924, "longitude": -118.1819, "latitude": 34.1226, "baro_altitude": 365.76, "geo_altitude": 358.14, "on_ground": false, "velocity": 34.53, "heading": 33.45, "vertical_rate": 0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:52:14.633274Z"}
# Successfully inserted row for icao24=ae277c into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=a384f8 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# BQML Prediction for icao24 a0c1d7: {'predicted_velocity': 89.37798092322129, 'altitude': 2095.5, 'vertical_rate': 0.0, 'heading': 328.44}
# Received message: {"icao24": "aa4421", "callsign": "N76015", "origin_country": "United States", "time_position": 1763671924, "last_contact": 1763671924, "longitude": -118.1297, "latitude": 34.1095, "baro_altitude": 899.16, "geo_altitude": 861.06, "on_ground": false, "velocity": 53.37, "heading": 107.39, "vertical_rate": 0.65, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:52:14.633274Z"}
# Successfully inserted row for icao24=aa7833 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=aaf0c3 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# BQML Prediction for icao24 a299f9: {'predicted_velocity': 64.25717605050401, 'altitude': 304.8, 'vertical_rate': 0.0, 'heading': 320.53}
# Received message: {"icao24": "a666cd", "callsign": "SKW6394", "origin_country": "United States", "time_position": 1763671924, "last_contact": 1763671924, "longitude": -118.3044, "latitude": 34.0056, "baro_altitude": 4701.54, "geo_altitude": 4747.26, "on_ground": false, "velocity": 191.06, "heading": 55.75, "vertical_rate": 9.1, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:52:14.633274Z"}
# BQML Prediction for icao24 a5c983: {'predicted_velocity': 77.5116461737213, 'altitude': 312.42, 'vertical_rate': 0.33, 'heading': 147.72}
# Received message: {"icao24": "ae277c", "callsign": "GH08", "origin_country": "United States", "time_position": 1763671911, "last_contact": 1763671911, "longitude": -118.1845, "latitude": 34.1196, "baro_altitude": 358.14, "geo_altitude": 358.14, "on_ground": false, "velocity": 33.97, "heading": 35.13, "vertical_rate": 0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:59.803585Z"}
# BQML Prediction for icao24 a9a120: {'predicted_velocity': 70.04380117200878, 'altitude': 381.0, 'vertical_rate': -0.33, 'heading': 259.25}
# Received message: {"icao24": "ae277c", "callsign": "GH08", "origin_country": "United States", "time_position": 1763671882, "last_contact": 1763671882, "longitude": -118.1909, "latitude": 34.1124, "baro_altitude": 335.28, "geo_altitude": 327.66, "on_ground": false, "velocity": 36.64, "heading": 38.16, "vertical_rate": 1.3, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:27.321835Z"}
# Successfully inserted row for icao24=aa4421 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# BQML Prediction for icao24 aadf08: {'predicted_velocity': 88.92224496961549, 'altitude': 320.04, 'vertical_rate': -0.33, 'heading': 0.0}
# Received message: {"icao24": "aa4421", "callsign": "N76015", "origin_country": "United States", "time_position": 1763671883, "last_contact": 1763671883, "longitude": -118.1511, "latitude": 34.1162, "baro_altitude": 899.16, "geo_altitude": 868.68, "on_ground": false, "velocity": 49.68, "heading": 111.25, "vertical_rate": 0.98, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:27.321835Z"}
# BQML Prediction for icao24 ab351f: {'predicted_velocity': 68.28608301343607, 'altitude': 68.58, 'vertical_rate': -2.93, 'heading': 225.76}
# Received message: {"icao24": "a9a120", "callsign": "N7199S", "origin_country": "United States", "time_position": 1763671882, "last_contact": 1763671883, "longitude": -118.2143, "latitude": 34.0116, "baro_altitude": 388.62, "geo_altitude": 381, "on_ground": false, "velocity": 69.63, "heading": 55.84, "vertical_rate": 0.98, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:27.321835Z"}
# Successfully inserted row for icao24=a666cd into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=ae277c into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=ae277c into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=a9a120 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=aa4421 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# BQML Prediction for icao24 ae277c: {'predicted_velocity': 86.87547731898574, 'altitude': 358.14, 'vertical_rate': 0.33, 'heading': 33.45}
# Received message: {"icao24": "aade5d", "callsign": "N8NF", "origin_country": "United States", "time_position": 1763671818, "last_contact": 1763671826, "longitude": -118.1747, "latitude": 34.196, "baro_altitude": 579.12, "geo_altitude": 548.64, "on_ground": false, "velocity": 40.75, "heading": 204.62, "vertical_rate": -5.2, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:27.321835Z"}
# BQML Prediction for icao24 aa7833: {'predicted_velocity': 83.232475822975, 'altitude': 830.58, 'vertical_rate': -3.25, 'heading': 173.55}
# Received message: {"icao24": "a5e790", "callsign": "N48PL", "origin_country": "United States", "time_position": 1763671883, "last_contact": 1763671883, "longitude": -118.4343, "latitude": 34.1645, "baro_altitude": 1356.36, "geo_altitude": 1341.12, "on_ground": false, "velocity": 114.48, "heading": 29.33, "vertical_rate": 12.03, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:27.321835Z"}
# Successfully inserted row for icao24=aade5d into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# BQML Prediction for icao24 a666cd: {'predicted_velocity': 147.62462503421494, 'altitude': 4747.26, 'vertical_rate': 9.1, 'heading': 55.75}
# Received message: {"icao24": "a5e739", "callsign": "N48KZ", "origin_country": "United States", "time_position": 1763671883, "last_contact": 1763671883, "longitude": -118.4922, "latitude": 34.2287, "baro_altitude": 342.9, "geo_altitude": 320.04, "on_ground": false, "velocity": 59.3, "heading": 176.02, "vertical_rate": -2.93, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:27.321835Z"}
# BQML Prediction for icao24 ae277c: {'predicted_velocity': 86.01219529728327, 'altitude': 327.66, 'vertical_rate': 1.3, 'heading': 38.16}
# Received message: {"icao24": "aadf08", "callsign": "N8VB", "origin_country": "United States", "time_position": 1763671879, "last_contact": 1763671882, "longitude": -118.4926, "latitude": 34.2077, "baro_altitude": 213.36, "geo_altitude": 137.16, "on_ground": false, "velocity": 0, "heading": 0, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:27.321835Z"}
# BQML Prediction for icao24 aa4421: {'predicted_velocity': 88.44397848938101, 'altitude': 861.06, 'vertical_rate': 0.65, 'heading': 107.39}
# Received message: {"icao24": "a299f9", "callsign": "N267LA", "origin_country": "United States", "time_position": 1763671882, "last_contact": 1763671882, "longitude": -118.2687, "latitude": 34.0681, "baro_altitude": 274.32, "geo_altitude": 259.08, "on_ground": false, "velocity": 35.22, "heading": 6.71, "vertical_rate": 0.98, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:27.321835Z"}
# BQML Prediction for icao24 a9a120: {'predicted_velocity': 85.45321372486029, 'altitude': 381.0, 'vertical_rate': 0.98, 'heading': 55.84}
# Received message: {"icao24": "a51633", "callsign": "LXJ427", "origin_country": "United States", "time_position": 1763671882, "last_contact": 1763671882, "longitude": -118.4867, "latitude": 34.2305, "baro_altitude": 6705.6, "geo_altitude": 6751.32, "on_ground": false, "velocity": 212.23, "heading": 331.63, "vertical_rate": 0, "squawk": "4757", "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:27.321835Z"}
# BQML Prediction for icao24 aaf0c3: {'predicted_velocity': 109.3677850832367, 'altitude': 2225.04, 'vertical_rate': -3.9, 'heading': 94.03}
# Received message: {"icao24": "ab351f", "callsign": "N821FR", "origin_country": "United States", "time_position": 1763671883, "last_contact": 1763671883, "longitude": -118.4354, "latitude": 34.0292, "baro_altitude": 213.36, "geo_altitude": 182.88, "on_ground": false, "velocity": 33.54, "heading": 221.27, "vertical_rate": -3.9, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:27.321835Z"}
# Successfully inserted row for icao24=a5e790 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=a5e739 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# BQML Prediction for icao24 aa4421: {'predicted_velocity': 88.23667963151993, 'altitude': 868.68, 'vertical_rate': 0.98, 'heading': 111.25}
# Received message: {"icao24": "a5c983", "callsign": "N472LA", "origin_country": "United States", "time_position": 1763671882, "last_contact": 1763671882, "longitude": -118.254, "latitude": 34.1215, "baro_altitude": 304.8, "geo_altitude": 289.56, "on_ground": false, "velocity": 30.56, "heading": 126.1, "vertical_rate": 1.3, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:27.321835Z"}
# Successfully inserted row for icao24=aadf08 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=a5c983 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=ab351f into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=a299f9 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=a51633 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# BQML Prediction for icao24 ae277c: {'predicted_velocity': 86.74746593115412, 'altitude': 358.14, 'vertical_rate': 0.33, 'heading': 35.13}
# Received message: {"icao24": "a0c1d7", "callsign": "EJA148", "origin_country": "United States", "time_position": 1763671883, "last_contact": 1763671883, "longitude": -118.2767, "latitude": 34.2273, "baro_altitude": 2110.74, "geo_altitude": 2095.5, "on_ground": false, "velocity": 147.89, "heading": 338.79, "vertical_rate": 0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:27.321835Z"}
# BQML Prediction for icao24 a384f8: {'predicted_velocity': 117.46199985656982, 'altitude': 2385.06, 'vertical_rate': 12.35, 'heading': 3.34}
# Received message: {"icao24": "a384f8", "callsign": "DAL483", "origin_country": "United States", "time_position": 1763671883, "last_contact": 1763671883, "longitude": -118.4429, "latitude": 34.2422, "baro_altitude": 1882.14, "geo_altitude": 1859.28, "on_ground": false, "velocity": 145.81, "heading": 352.5, "vertical_rate": 13.98, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:27.321835Z"}
# Successfully inserted row for icao24=a0c1d7 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=a384f8 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# BQML Prediction for icao24 a5e739: {'predicted_velocity': 75.68837416321851, 'altitude': 320.04, 'vertical_rate': -2.93, 'heading': 176.02}
# Received message: {"icao24": "aa7833", "callsign": "DAL1715", "origin_country": "United States", "time_position": 1763671882, "last_contact": 1763671883, "longitude": -118.1749, "latitude": 34.0453, "baro_altitude": 1021.08, "geo_altitude": 1013.46, "on_ground": false, "velocity": 94.76, "heading": 96.55, "vertical_rate": -6.83, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:27.321835Z"}
# BQML Prediction for icao24 aade5d: {'predicted_velocity': 76.9487176503731, 'altitude': 548.64, 'vertical_rate': -5.2, 'heading': 204.62}
# Received message: {"icao24": "aa7833", "callsign": "DAL1715", "origin_country": "United States", "time_position": 1763671910, "last_contact": 1763671910, "longitude": -118.1585, "latitude": 34.0287, "baro_altitude": 876.3, "geo_altitude": 868.68, "on_ground": false, "velocity": 91.02, "heading": 171.55, "vertical_rate": -2.93, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:59.803585Z"}
# BQML Prediction for icao24 aadf08: {'predicted_velocity': 86.2725222852707, 'altitude': 137.16, 'vertical_rate': 0.0, 'heading': 0.0}
# Received message: {"icao24": "aa4421", "callsign": "N76015", "origin_country": "United States", "time_position": 1763671911, "last_contact": 1763671911, "longitude": -118.1368, "latitude": 34.1116, "baro_altitude": 906.78, "geo_altitude": 876.3, "on_ground": false, "velocity": 51.68, "heading": 112.23, "vertical_rate": -1.3, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:59.803585Z"}
# Successfully inserted row for icao24=aa4421 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# BQML Prediction for icao24 a5c983: {'predicted_velocity': 78.76409967643988, 'altitude': 289.56, 'vertical_rate': 1.3, 'heading': 126.1}
# Received message: {"icao24": "a9a120", "callsign": "N7199S", "origin_country": "United States", "time_position": 1763671911, "last_contact": 1763671911, "longitude": -118.2196, "latitude": 34.024, "baro_altitude": 396.24, "geo_altitude": 381, "on_ground": false, "velocity": 72.21, "heading": 265.91, "vertical_rate": -0.65, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:59.803585Z"}
# BQML Prediction for icao24 a5e790: {'predicted_velocity': 100.50731857611632, 'altitude': 1341.12, 'vertical_rate': 12.03, 'heading': 29.33}
# Received message: {"icao24": "aade5d", "callsign": "N8NF", "origin_country": "United States", "time_position": 1763671818, "last_contact": 1763671826, "longitude": -118.1747, "latitude": 34.196, "baro_altitude": 579.12, "geo_altitude": 548.64, "on_ground": false, "velocity": 40.75, "heading": 204.62, "vertical_rate": -5.2, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:59.803585Z"}
# Successfully inserted row for icao24=aa7833 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# BQML Prediction for icao24 a299f9: {'predicted_velocity': 87.4453958995227, 'altitude': 259.08, 'vertical_rate': 0.98, 'heading': 6.71}
# Received message: {"icao24": "a5e790", "callsign": "N48PL", "origin_country": "United States", "time_position": 1763671911, "last_contact": 1763671911, "longitude": -118.4371, "latitude": 34.1927, "baro_altitude": 1767.84, "geo_altitude": 1760.22, "on_ground": false, "velocity": 118.69, "heading": 330.1, "vertical_rate": 14.96, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:59.803585Z"}
# Successfully inserted row for icao24=aa7833 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=a5e790 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# BQML Prediction for icao24 a384f8: {'predicted_velocity': 83.19227734191844, 'altitude': 1859.28, 'vertical_rate': 13.98, 'heading': 352.5}
# Received message: {"icao24": "a5e739", "callsign": "N48KZ", "origin_country": "United States", "time_position": 1763671910, "last_contact": 1763671911, "longitude": -118.4908, "latitude": 34.214, "baro_altitude": 236.22, "geo_altitude": 220.98, "on_ground": false, "velocity": 56.78, "heading": 175.32, "vertical_rate": -2.6, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:59.803585Z"}
# Successfully inserted row for icao24=aade5d into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# BQML Prediction for icao24 ab351f: {'predicted_velocity': 70.33668154008318, 'altitude': 182.88, 'vertical_rate': -3.9, 'heading': 221.27}
# Received message: {"icao24": "aadf08", "callsign": "N8VB", "origin_country": "United States", "time_position": 1763671908, "last_contact": 1763671910, "longitude": -118.494, "latitude": 34.2071, "baro_altitude": 213.36, "geo_altitude": 144.78, "on_ground": false, "velocity": 0, "heading": 0, "vertical_rate": -0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:59.803585Z"}
# Successfully inserted row for icao24=aadf08 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=a5e739 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# Successfully inserted row for icao24=a9a120 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# BQML Prediction for icao24 a51633: {'predicted_velocity': 156.01607708928745, 'altitude': 6751.32, 'vertical_rate': 0.0, 'heading': 331.63}
# Received message: {"icao24": "a299f9", "callsign": "N267LA", "origin_country": "United States", "time_position": 1763671911, "last_contact": 1763671911, "longitude": -118.2677, "latitude": 34.0771, "baro_altitude": 304.8, "geo_altitude": 289.56, "on_ground": false, "velocity": 33.63, "heading": 6.15, "vertical_rate": 2.6, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:59.803585Z"}
# Successfully inserted row for icao24=a299f9 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# BQML Prediction for icao24 a0c1d7: {'predicted_velocity': 88.56670007342682, 'altitude': 2095.5, 'vertical_rate': 0.33, 'heading': 338.79}
# Received message: {"icao24": "ab351f", "callsign": "N821FR", "origin_country": "United States", "time_position": 1763671911, "last_contact": 1763671911, "longitude": -118.4416, "latitude": 34.0241, "baro_altitude": 137.16, "geo_altitude": 114.3, "on_ground": false, "velocity": 28.38, "heading": 223.53, "vertical_rate": -2.28, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:59.803585Z"}
# Successfully inserted row for icao24=ab351f into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# BQML Prediction for icao24 aa4421: {'predicted_velocity': 88.4278848645402, 'altitude': 876.3, 'vertical_rate': -1.3, 'heading': 112.23}
# Received message: {"icao24": "a5c983", "callsign": "N472LA", "origin_country": "United States", "time_position": 1763671911, "last_contact": 1763671911, "longitude": -118.2457, "latitude": 34.1176, "baro_altitude": 327.66, "geo_altitude": 312.42, "on_ground": false, "velocity": 34.26, "heading": 131.35, "vertical_rate": -0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:59.803585Z"}
# Successfully inserted row for icao24=a5c983 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# BQML Prediction for icao24 aadf08: {'predicted_velocity': 86.40462335849594, 'altitude': 144.78, 'vertical_rate': -0.33, 'heading': 0.0}
# Received message: {"icao24": "a0c1d7", "callsign": "EJA148", "origin_country": "United States", "time_position": 1763671911, "last_contact": 1763671911, "longitude": -118.2927, "latitude": 34.2619, "baro_altitude": 2110.74, "geo_altitude": 2095.5, "on_ground": false, "velocity": 144.27, "heading": 339.11, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:59.803585Z"}
# Successfully inserted row for icao24=a0c1d7 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# BQML Prediction for icao24 aa7833: {'predicted_velocity': 91.972349565208, 'altitude': 1013.46, 'vertical_rate': -6.83, 'heading': 96.55}
# Received message: {"icao24": "a384f8", "callsign": "DAL483", "origin_country": "United States", "time_position": 1763671911, "last_contact": 1763671911, "longitude": -118.4483, "latitude": 34.2787, "baro_altitude": 2263.14, "geo_altitude": 2240.28, "on_ground": false, "velocity": 147.03, "heading": 353.57, "vertical_rate": 13.66, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:59.803585Z"}
# BQML Prediction for icao24 a5e739: {'predicted_velocity': 74.29606945810711, 'altitude': 220.98, 'vertical_rate': -2.6, 'heading': 175.32}
# Received message: {"icao24": "aaf0c3", "callsign": "ASA505", "origin_country": "United States", "time_position": 1763671911, "last_contact": 1763671911, "longitude": -118.4884, "latitude": 34.0132, "baro_altitude": 2293.62, "geo_altitude": 2278.38, "on_ground": false, "velocity": 141.74, "heading": 96.04, "vertical_rate": -3.25, "squawk": "1660", "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T20:51:59.803585Z"}
# Successfully inserted row for icao24=a384f8 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# BQML Prediction for icao24 a5e790: {'predicted_velocity': 83.40886057317759, 'altitude': 1760.22, 'vertical_rate': 14.96, 'heading': 330.1}
# BQML Prediction for icao24 aade5d: {'predicted_velocity': 76.9487176503731, 'altitude': 548.64, 'vertical_rate': -5.2, 'heading': 204.62}
# BQML Prediction for icao24 aa7833: {'predicted_velocity': 83.91022615245224, 'altitude': 868.68, 'vertical_rate': -2.93, 'heading': 171.55}
# Successfully inserted row for icao24=aaf0c3 into heroic-trilogy-471119-k8.training_dataset.realtime_flight_data
# BQML Prediction for icao24 a9a120: {'predicted_velocity': 69.5582806817037, 'altitude': 381.0, 'vertical_rate': -0.65, 'heading': 265.91}
# BQML Prediction for icao24 a299f9: {'predicted_velocity': 87.81477539353232, 'altitude': 289.56, 'vertical_rate': 2.6, 'heading': 6.15}
# BQML Prediction for icao24 ab351f: {'predicted_velocity': 69.06818125661844, 'altitude': 114.3, 'vertical_rate': -2.28, 'heading': 223.53}
# BQML Prediction for icao24 a0c1d7: {'predicted_velocity': 88.5649562159812, 'altitude': 2095.5, 'vertical_rate': 0.0, 'heading': 339.11}
# BQML Prediction for icao24 a384f8: {'predicted_velocity': 88.60578996412774, 'altitude': 2240.28, 'vertical_rate': 13.66, 'heading': 353.57}
# BQML Prediction for icao24 a5c983: {'predicted_velocity': 78.8042737606252, 'altitude': 312.42, 'vertical_rate': -0.33, 'heading': 131.35}
# BQML Prediction for icao24 aaf0c3: {'predicted_velocity': 109.93626877583267, 'altitude': 2278.38, 'vertical_rate': -3.25, 'heading': 96.04}
# Listening timed out. No messages received within the specified duration.
#
# BQML Prediction Results (DataFrame Head):
#    predicted_velocity  altitude  vertical_rate  heading
# 0           89.945158    876.30           0.33    90.85
# 1           84.416134   1943.10          15.28   351.07
# 2           76.948718    548.64          -5.20   204.62
# 3           73.920653    205.74          -0.33   175.33
# 4           89.377981   2095.50           0.00   328.44
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['predicted_velocity'].plot(kind='hist', bins=20, title='predicted_velocity')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['altitude'].plot(kind='hist', bins=20, title='altitude')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['vertical_rate'].plot(kind='hist', bins=20, title='vertical_rate')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['heading'].plot(kind='hist', bins=20, title='heading')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='predicted_velocity', y='altitude', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='altitude', y='vertical_rate', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='vertical_rate', y='heading', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_7['predicted_velocity'].plot(kind='line', figsize=(8, 4), title='predicted_velocity')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8['altitude'].plot(kind='line', figsize=(8, 4), title='altitude')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['vertical_rate'].plot(kind='line', figsize=(8, 4), title='vertical_rate')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['heading'].plot(kind='line', figsize=(8, 4), title='heading')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ## 9. Visualization (Predicted vs Actual)
#
# Context: Scatter plot of the results.
#
# Prompt: "Using matplotlib and seaborn, write code to visualize the prediction results stored in the predictions_df DataFrame. Create a scatter plot where the x-axis is 'heading' and the y-axis is 'predicted_velocity'. Color the points based on the predicted velocity using a 'viridis' palette."

# %%
import matplotlib.pyplot as plt
import seaborn as sns

if 'predictions_df' in locals() and not predictions_df.empty:
    plt.figure(figsize=(10, 6))
    sns.scatterplot(x='heading', y='predicted_velocity', data=predictions_df, hue='predicted_velocity', palette='viridis')
    plt.title('Predicted Velocity vs. Heading')
    plt.xlabel('Heading (degrees)')
    plt.ylabel('Predicted Velocity')
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.show()
else:
    print("predictions_df is not available or empty. Please ensure predictions are generated first.")

# %% [markdown]
# ## 10. Flight Path Query & Visualization
#
# Context: Queries historical data for a specific plane and plots the path.
#
# Prompt: "Write a code block that:
#
# Creates an input form field for CALLSIGN_TO_TRACK (defaulting to 'DAL339').
#
# Queries the BigQuery table realtime_flight_data to retrieve the longitude, latitude, geo_altitude, and velocity for that callsign, ordered by timestamp.
#
# Stores the result in a DataFrame.
#
# Uses Seaborn to plot a line chart of Longitude vs. Latitude to visualize the flight path.
#
# Mark the start position with a green dot and the end position with a red dot."

# %% [markdown]
# **Note:** For the Callsign, I used "DAL2975" to create my visualizations instead of "DAL339" because "DAL339" did not exist in my BigQuery Table.

# %%
#@title Enter the Callsign to Track
CALLSIGN_TO_TRACK = 'DAL2975' #@param {type:"string"}

print(f"You chose to track flight with Callsign: {CALLSIGN_TO_TRACK}")
# Out:
# You chose to track flight with Callsign: DAL2975

# %%
from google.cloud import bigquery
import pandas as pd

bq_client = bigquery.Client(project=PROJECT_ID)

print(f"Fetching flight data for callsign: {CALLSIGN_TO_TRACK}...")

flight_path_query = f"""
SELECT
    sensor_timestamp,
    longitude,
    latitude,
    geo_altitude,
    velocity,
    heading,
    vertical_rate
FROM
    `{PROJECT_ID}.{BQ_DATASET}.{BQ_TABLE_REALTIME}`
WHERE
    callsign = '{CALLSIGN_TO_TRACK}'
ORDER BY
    sensor_timestamp ASC
"""

flight_path_job = bq_client.query(flight_path_query)
flight_path_df = flight_path_job.to_dataframe()

if not flight_path_df.empty:
    print(f"Found {len(flight_path_df)} records for {CALLSIGN_TO_TRACK}.")
    display(flight_path_df.head())
else:
    print(f"No flight data found for callsign: {CALLSIGN_TO_TRACK}")
# Out:
# Fetching flight data for callsign: DAL2975...
# Found 2 records for DAL2975.
#                   sensor_timestamp  longitude  latitude  geo_altitude  \
# 0 2025-11-20 20:32:49.659712+00:00  -118.2410   34.0391        937.26
# 1 2025-11-20 20:33:08.869538+00:00  -118.2172   34.0416        784.86
#
#    velocity  heading  vertical_rate
# 0    110.78     83.6          -8.78
# 1    107.90     82.6          -3.90

# %%
import matplotlib.pyplot as plt
import seaborn as sns

if 'flight_path_df' in locals() and not flight_path_df.empty:
    plt.figure(figsize=(12, 8))
    sns.lineplot(x='longitude', y='latitude', data=flight_path_df, marker='o', sort=False)
    plt.title(f'Flight Path for Callsign: {CALLSIGN_TO_TRACK}')
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.grid(True, linestyle='--', alpha=0.7)

    # Optionally, add start and end points
    if len(flight_path_df) > 0:
        plt.plot(flight_path_df['longitude'].iloc[0], flight_path_df['latitude'].iloc[0], 'go', markersize=10, label='Start') # Green circle for start
        plt.plot(flight_path_df['longitude'].iloc[-1], flight_path_df['latitude'].iloc[-1], 'ro', markersize=10, label='End') # Red circle for end

    plt.legend()
    plt.show()
else:
    print("No flight path data available to plot.")

# %% [markdown]
# ## 11. Classification Model Prediction
#
# Context: Using a different model to classify if a plane is on the ground.
#
# Prompt: "Write a script to perform classification using BigQuery ML.
#
# Define a model name flight_on_ground_classifier.
#
# Construct a SQL query that uses ML.PREDICT with this model.
#
# The input data for the prediction should be the most recent 100 records from the realtime_flight_data table (selecting icao24, geo_altitude, and velocity).
#
# Execute the query and display the classification results in a DataFrame."

# %%
# Define the classification model name
CLASSIFICATION_MODEL_NAME = "flight_on_ground_classifier"

print(f"Classification Model: {CLASSIFICATION_MODEL_NAME}")
# Out:
# Classification Model: flight_on_ground_classifier

# %%
from google.cloud import bigquery
import pandas as pd

bq_client = bigquery.Client(project=PROJECT_ID)

print(f"Running classification predictions using model: {CLASSIFICATION_MODEL_NAME}...")

# Construct the prediction query for the classification model
# We will use the latest data inserted into realtime_flight_data as input
classification_predict_query = f"""
SELECT
    * EXCEPT(predicted_on_ground_probs)
FROM
    ML.PREDICT(MODEL `{PROJECT_ID}.{BQ_DATASET}.{CLASSIFICATION_MODEL_NAME}`,
        (SELECT
            icao24,
            geo_altitude AS altitude, # Alias geo_altitude to altitude as required by model
            velocity
         FROM
            `{PROJECT_ID}.{BQ_DATASET}.{BQ_TABLE_REALTIME}`
         LIMIT 100 # Limit to avoid processing too much data for demonstration
         ))
"""

classification_predict_job = bq_client.query(classification_predict_query)
classification_predictions = classification_predict_job.result()

# Convert results to a Pandas DataFrame for easy viewing
classification_predictions_df = classification_predictions.to_dataframe()

if not classification_predictions_df.empty:
    print("\nBQML Classification Prediction Results (DataFrame Head):")
    display(classification_predictions_df.head())
else:
    print("No classification predictions were generated.")
# Out:
# Running classification predictions using model: flight_on_ground_classifier...
#
# BQML Classification Prediction Results (DataFrame Head):
#    predicted_on_ground  icao24  altitude  velocity
# 0                    0  a2f3d4    563.88     58.66
# 1                    0  a9a120    373.38     69.46
# 2                    0  a299f9    167.64     30.68
# 3                    0  a99272    205.74     55.75
# 4                    0  adf0a3   1775.46    127.06
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_19['altitude'].plot(kind='hist', bins=20, title='altitude')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_20['velocity'].plot(kind='hist', bins=20, title='velocity')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_21.groupby('icao24').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_22.plot(kind='scatter', x='altitude', y='velocity', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_23['altitude'].plot(kind='line', figsize=(8, 4), title='altitude')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_24['velocity'].plot(kind='line', figsize=(8, 4), title='velocity')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_25['icao24'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_25, x='altitude', y='icao24', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_26['icao24'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_26, x='velocity', y='icao24', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
